# %% [markdown]
# # NIFTY-50 EDA
# Exploratory analysis over the processed panel using the platform's reusable plotting functions.
# Run `python -m backend.data_loader` first (or let it auto-generate synthetic demo data).

# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path.cwd().parent))
from backend.data_loader import load_processed
from ml import eda

data = load_processed()
panel = data['panel']
symbols = sorted(panel['Symbol'].unique())
panel.tail()

# %%
eda.plot_price_trends(panel, symbols[:8])

# %%
eda.plot_sector_comparison(panel)

# %%
eda.plot_correlation_heatmap(panel)

# %%
eda.plot_return_distribution(panel, symbols[0])

# %%
eda.plot_volatility(panel, symbols[:8])

# %%
eda.plot_drawdown(panel, symbols[0])
